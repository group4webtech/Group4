# %% [markdown]
# # NetworkX Visualization Powered by Bokeh
#
# <br>
# ### EuroPython 2016 (2016-07-22)
#
# ###### Björn Meier

# %% [markdown]
# ### Original Objectives:
# * exploring networks for patterns based on properties like node centrality or clustering
# * visualization in a browser
#
# <br>

# %% [markdown]
# ### Original Solution:
# * generate networks and properties
# * RESTful Flask app to provide data
# * D3.js app for browser visualization

# %% [markdown]
# ## Can we solve this easier?

# %% [markdown]
# ### NetworkX + Bokeh
#
# * define the visualization in pure python
# * interact with your network
#     * change views or change showed properties
#     * manipulate the network and get an updated plot
# * possible embedding in a web app

# %% [markdown]
# #### Now, I will show you how it is done ...

# %% [markdown]
# ## Step 0: Example Data

# %% [markdown]
# <img src=europython-2016-logo-white-bg.png width=400 />

# %% [markdown]
# <img src=twitter.png width=200 />

# %% [markdown]
# * tweets during Europython 2016 @europython
# * author will be linked with users mentioned in a tweet

# %% [markdown]
# ## Step 1: Create a Network

# %%
import networkx
from math import sqrt
network = networkx.read_gml('ep2016.gml')

layout = networkx.spring_layout(network,
                                k=1.1/sqrt(network.number_of_nodes()),
                                iterations=100)
# https://en.wikipedia.org/wiki/Force-directed_graph_drawing

# %% [markdown]
# ![elastic network](images/elastic_network.png)
#
# <sub>Image: https://en.wikipedia.org/wiki/Spring_system</sub>

# %% [markdown]
# * Only nice took look at
# * Flattened into 2D
# * Not accurate

# %% [markdown]
# ## The Cornerstone is the ColumnDataSource
#
# | (id)  | x   | y   | node_name | ... |
# |:-----:|:---:|:---:|:---------:|:---:|
# | 0     | 21  | 3   | da_bjoerni| ... |
# | 1     | 14  | 7   | user47    | ... |
# | ...   | ... | ... | ...       | ... |
#
# * column based data class
# * columns must be sequences of data e.g. lists, pandas.DataFrame, ...
# * changes will effect the plot during a rerendering
# * selection information inside a plot

# %%
from bokeh.models import ColumnDataSource

nodes, nodes_coordinates = zip(*sorted(layout.items()))
nodes_xs, nodes_ys = list(zip(*nodes_coordinates))
nodes_source = ColumnDataSource(dict(x=nodes_xs, y=nodes_ys,
                                     name=nodes))

# %% [markdown]
# ## Step 2: Plot a Network

# %%
from bokeh.plotting import show, figure
from bokeh.io import output_notebook
from bokeh.models import HoverTool

hover = HoverTool(tooltips=[('name', '@name'), ('id', '$index')])
plot = figure(plot_width=800, plot_height=400,
              tools=['tap', hover, 'box_zoom', 'reset'])
r_circles = plot.circle('x', 'y', source=nodes_source, size=10,
                        color='blue', level = 'overlay')

# %%
output_notebook(); show(plot)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="22a117d4-300a-41a0-a31f-b65afdb5d0b2">Loading BokehJS ...</span>
#     </div>
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="3dac0dca-4ef0-4868-9722-1bdf3226e8e4"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("3dac0dca-4ef0-4868-9722-1bdf3226e8e4");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("3dac0dca-4ef0-4868-9722-1bdf3226e8e4");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '3dac0dca-4ef0-4868-9722-1bdf3226e8e4' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"0359ffa2-88c6-4f44-bcee-3a501a94b69d":{"roots":{"references":[{"attributes":{"source":{"id":"129c6b73-7942-4a9e-9755-5ab8bcb23524","type":"ColumnDataSource"}},"id":"c4715fad-6ee4-4a65-822a-05079d69cee3","type":"CDSView"},{"attributes":{"plot":null,"text":""},"id":"a3195b2d-52ad-43cc-97d2-f6d56ae64097","type":"Title"},{"attributes":{"fill_color":{"value":"blue"},"line_color":{"value":"blue"},"size":{"units":"screen","value":10},"x":{"field":"x"},"y":{"field":"y"}},"id":"b
subtype":"Figure","type":"Plot"},"ticker":{"id":"8f952c5e-2bd0-4980-9c34-bfe10dcd11c0","type":"BasicTicker"}},"id":"1c683bd3-b443-4eea-b2e3-b7ea62d760df","type":"LinearAxis"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"scr ...

# %% [markdown]
# # Step 3: Add the edges
#
# ### Prepare the networkX edges

# %%
def get_edges_specs(_network, _layout):
    d = dict(xs=[], ys=[], alphas=[])
    weights = [d['weight'] for u, v, d in _network.edges(data=True)]
    max_weight = max(weights)
    calc_alpha = lambda h: 0.1 + 0.6 * (h / max_weight)

    # example: { ..., ('user47', 'da_bjoerni', {'weight': 3}), ... }
    for u, v, data in _network.edges(data=True):
        d['xs'].append([_layout[u][0], _layout[v][0]])
        d['ys'].append([_layout[u][1], _layout[v][1]])
        d['alphas'].append(calc_alpha(data['weight']))
    return d

# %% [markdown]
# ### Create a ColumnDataSource for the edges

# %%
lines_source = ColumnDataSource(get_edges_specs(network, layout))

# %%
r_lines = plot.multi_line('xs', 'ys', line_width=1.5,
                          alpha='alphas', color='navy',
                          source=lines_source)
show(plot)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="5baef8c4-6ca9-4af7-a309-8f2787a3195d"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("5baef8c4-6ca9-4af7-a309-8f2787a3195d");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("5baef8c4-6ca9-4af7-a309-8f2787a3195d");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '5baef8c4-6ca9-4af7-a309-8f2787a3195d' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"8a038fbf-2c8f-4909-bd37-c9b3ab6015bf":{"roots":{"references":[{"attributes":{"source":{"id":"129c6b73-7942-4a9e-9755-5ab8bcb23524","type":"ColumnDataSource"}},"id":"c4715fad-6ee4-4a65-822a-05079d69cee3","type":"CDSView"},{"attributes":{"plot":null,"text":""},"id":"a3195b2d-52ad-43cc-97d2-f6d56ae64097","type":"Title"},{"attributes":{"fill_color":{"value":"blue"},"line_color":{"value":"blue"},"size":{"units":"screen","value":10},"x":{"field":"x"},"y":{"field":"y"}},"id":"bb53f5b0-f354-486b-a65a-731c3b2c0a72","type":"Circle"},{"attributes":{"callback":null,"column_names":["xs","ys","alphas"],"data":{"alphas":[0.1206896551724138,0.3275862068965517,0.1413793103448276,0.18275862068965518,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1413793103448276,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1413793103448276,0.16206896551724137,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.16206896551724137,0.1206896551724138,0.1413793103448276,0.1206896551724138,0.1206896551724138,0.1413793103448276,0.16206896551724137,0.1206896551724138,0.1206896551724138,0.22413793103448276,0.16206896551724137,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.2655172413793103,0.18275862068965518,0.1413793103448276,0.20344827586206898,0.1206896551724138,0.3275862068965517,0.1206896551724138,0.1206896551724138,0.1413793103448276,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1413793103448276,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.18275862068965518,0.1206896551724138,0.1206896551724138,0.16206896551724137,0.1206896551724138,0.1206896551724138,0.1413793103448276,0.1413793103448276,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.16206896551724137,0.1206896551724138,0.16206896551724137,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1413793103448276,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.34827586206896555,0.34827586206896555,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1413793103448276,0.1206896551724138,0.1206896551724138,0.1413793103448276,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.2655172413793103,0.18275862068965518,0.1206896551724138,0.1206896551724138,0.22413793103448276,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1413793103448276,0.1206896551724138,0.1206896551724138,0.16206896551724137,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.7,0.1206896551724138,0.1206896551724138,0.18275862068965518,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1413793103448276,0.1413793103448276,0.2655172413793103,0.1413793103448276,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.18275862068965518,0.1206896551724138,0.1206896551724138,0.18275862068965518,0.1206896551724138,0.1206896551724138,0.1413793103448276,0.1413793103448276,0.24482758620689657,0.16206896551724137,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.16206896551724137,0.1206896551724138,0.1413793103448276,0.1206896551724138,0.1206896551724138,0.18275862068965518,0.1413793103448276,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1 ...

# %% [markdown]
# # Step 4: Visualize properties
#
# ### Add Clustering and Centrality to ColumnDataSource

# %%
centrality =\
    networkx.algorithms.centrality.betweenness_centrality(network)
# first element are nodes again
_, nodes_centrality = zip(*sorted(centrality.items()))
max_centraliy = max(nodes_centrality)
nodes_source.add([7 + 10 * t / max_centraliy
                  for t in nodes_centrality],
                 'centrality')
# Out:
# 'centrality'

# %%
import community # python-louvain
partition = community.best_partition(network)
p_, nodes_community = zip(*sorted(partition.items()))
nodes_source.add(nodes_community, 'community')
community_colors = ['#e41a1c','#377eb8','#4daf4a','#984ea3','#ff7f00','#ffff33','#a65628', '#b3cde3','#ccebc5','#decbe4','#fed9a6','#ffffcc','#e5d8bd','#fddaec','#1b9e77','#d95f02','#7570b3','#e7298a','#66a61e','#e6ab02','#a6761d','#666666']
nodes_source.add([community_colors[t % len(community_colors)]
                  for t in nodes_community],
                 'community_color')
# Out:
# 'community_color'

# %% [markdown]
# ### Update the Renderer

# %%
r_circles.glyph.size = 'centrality'
r_circles.glyph.fill_color = 'community_color'

# %%
show(plot)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="f874569d-df43-4679-adfa-9b949c2a27db"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(root) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (root._bokeh_onload_callbacks) === "undefined" || force === true) {
#       root._bokeh_onload_callbacks = [];
#       root._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (root._bokeh_timeout) === "undefined" || force === true) {
#       root._bokeh_timeout = Date.now() + 0;
#       root._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (root.Bokeh !== undefined) {
#         var el = document.getElementById("f874569d-df43-4679-adfa-9b949c2a27db");
#         if (el != null) {
#           el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#         }
#       } else if (Date.now() < root._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#
#     function run_callbacks() {
#       try {
#         root._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete root._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       root._bokeh_onload_callbacks.push(callback);
#       if (root._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       root._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           root._bokeh_is_loading--;
#           if (root._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("f874569d-df43-4679-adfa-9b949c2a27db");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'f874569d-df43-4679-adfa-9b949c2a27db' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"d39fd40a-0c41-43ff-85b4-44da1060ba6a":{"roots":{"references":[{"attributes":{"source":{"id":"129c6b73-7942-4a9e-9755-5ab8bcb23524","type":"ColumnDataSource"}},"id":"c4715fad-6ee4-4a65-822a-05079d69cee3","type":"CDSView"},{"attributes":{"plot":null,"text":""},"id":"a3195b2d-52ad-43cc-97d2-f6d56ae64097","type":"Title"},{"attributes":{"fill_color":{"field":"community_color"},"line_color":{"value":"blue"},"size":{"field":"centrality","units":"screen"},"x":{"field":"x"},"y":{"field":"y"}},"id":"bb53f5b0-f354-486b-a65a-731c3b2c0a72","type":"Circle"},{"attributes":{"callback":null,"column_names":["xs","ys","alphas"],"data":{"alphas":[0.1206896551724138,0.3275862068965517,0.1413793103448276,0.18275862068965518,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1413793103448276,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1413793103448276,0.16206896551724137,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.16206896551724137,0.1206896551724138,0.1413793103448276,0.1206896551724138,0.1206896551724138,0.1413793103448276,0.16206896551724137,0.1206896551724138,0.1206896551724138,0.22413793103448276,0.16206896551724137,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.2655172413793103,0.18275862068965518,0.1413793103448276,0.20344827586206898,0.1206896551724138,0.3275862068965517,0.1206896551724138,0.1206896551724138,0.1413793103448276,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1413793103448276,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.18275862068965518,0.1206896551724138,0.1206896551724138,0.16206896551724137,0.1206896551724138,0.1206896551724138,0.1413793103448276,0.1413793103448276,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.16206896551724137,0.1206896551724138,0.16206896551724137,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1413793103448276,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.34827586206896555,0.34827586206896555,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1413793103448276,0.1206896551724138,0.1206896551724138,0.1413793103448276,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.2655172413793103,0.18275862068965518,0.1206896551724138,0.1206896551724138,0.22413793103448276,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1413793103448276,0.1206896551724138,0.1206896551724138,0.16206896551724137,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.7,0.1206896551724138,0.1206896551724138,0.18275862068965518,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1413793103448276,0.1413793103448276,0.2655172413793103,0.1413793103448276,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.18275862068965518,0.1206896551724138,0.1206896551724138,0.18275862068965518,0.1206896551724138,0.1206896551724138,0.1413793103448276,0.1413793103448276,0.24482758620689657,0.16206896551724137,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.16206896551724137,0.1206896551724138,0.1413793103448276,0.1206896551724138,0.1206896551724138,0.18275862068965518,0.1413793103448276,0.1206896551724138,0.1206896551724138,0.1206896551724138,0.1206896551724138,0 ...

# %% [markdown]
# # Step 5: Interactions

# %% [markdown]
# ### Get Selected Nodes
#
# `ColumnDataSource.selected`
# ```python
# {
#  # line or patch glyph selections
#  '0d': {'get_view': {}, 'glyph': None,
#         'indices': []},
#  # all other glyph selections
#  '1d': {'indices': [73]},
#  # [multi]line or patch selections
#  '2d': {'indices': []}
# }
# ```

# %% [markdown]
# ### Remove Node

# %%
def remove_node():
    idx = nodes_source.selected['1d']['indices'][0]
    
    # update networkX network
    node = nodes_source.data['name'][idx]
    network.remove_node(node)
    
    # update layout
    layout.pop(node)
    
    # update nodes ColumnDataSource
    new_source_data = dict()
    for column in nodes_source.column_names:
        new_source_data[column] =\
        [e for i, e in enumerate(nodes_source.data[column])
         if i != idx]
    nodes_source.data = new_source_data

    # update lines ColumnDataSource
    lines_source.data = get_edges_specs(network, layout)

# %% [markdown]
# ### Notebook Limitations
# * no direct redraw after changing the ColumnDataSource
# * getting selected nodes is not working
# * can not run arbitrary python code started by widges, e.g. buttons
#
# <br>
#
# ### Bokeh Server
# ```
# bokeh serve your_app.py
# ```
#
# [http://localhost:5006/bokehx_app](http://localhost:5006/bokehx_app)

# %% [markdown]
# # Thank You
#
# The slides and code can be found at:
#
# [https://github.com/blue-yonder/documents](https://github.com/blue-yonder/documents)
#
# <br>
# ## NetworkX
# [https://networkx.github.io](https://networkx.github.io)
#
# <br>
# ## Bokeh
# [http://bokeh.pydata.org](http://bokeh.pydata.org)
